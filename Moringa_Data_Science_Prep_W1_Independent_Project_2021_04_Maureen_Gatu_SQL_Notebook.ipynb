# %% [markdown]
# <a href="https://colab.research.google.com/github/MaureenGatu/Gatu-Moringa/blob/main/Moringa_Data_Science_Prep_W1_Independent_Project_2021_04_Maureen_Gatu_SQL_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SQL Programming Questions

#Display a list of Sub Counties and their population and areas.
#Sort the list of districts by total crop area (descending order).
#Select only the Sub counties from the Moroto district, order them alphabetically
#  and show their production of sorghum.
#Compute the total Maize production per District.
#Compute the number of Sub counties where Maize is produced and the total Maize production per District.
#Compute the overall Crop area in all Sub counties where population is over 20000.
#Sort the Maize production in descending order by Districts, only taking into account
#  Sub counties where Maize area is larger than Sorghum area, and display the
#   number of Sub counties per district matching that criteria.

# %%
#importing table
# %load_ext sql
# %sql sqlite://
import csv
import pandas as pd
with open('/content/Uganda_Karamoja_Subcounty_Crop_Yield_Population.csv','r') as f:
    Uganda = pd.read_csv(f, index_col=0, encoding='utf-8') 
#%sql DROP TABLE if EXISTS Transactions;
# %sql PERSIST Uganda;
# Out:
#  * sqlite://
# 'Persisted uganda'

# %%
#Display a list of Sub Counties and their population and areas.

# %%sql
SELECT SUBCOUNTY_NAME, POP, Area from Uganda;
# Out:
#  * sqlite://
# Done.
# [('KACHERI', 17244, 1067176155),
#  ('KOTIDO', 52771, 597575188),
#  ('KOTIDO TOWN COUNCIL', 27389, 23972401),
#  ('NAKAPERIMORU', 38775, 419111591),
#  ('PANYANGARA', 65704, 880955930),
#  ('RENGEN', 41273, 652744859),
#  ('KAABONG  EAST', 42221, 60801942),
#  ('KAABONG TOWN COUNCIL', 38857, 13071455),
#  ('KAABONG WEST', 41454, 67612362),
#  ('KALAPATA', 99203, 223116860),
#  ('KAMION', 60070, 1199409465),
#  ('KAPEDO', 33951, 304557831),
#  ('KATHILE', 56870, 228457417),
#  ('KAWALAKOL', 37691, 1742041261),
#  ('LOBALANGIT', 22907, 302572789),
#  ('LODIKO', 31820, 397700845),
#  ('LOLELIA', 100919, 1069331387),
#  ('LOYORO', 16608, 1330019236),
#  ('NAPORE (KARENGA)', 20394, 309577387),
#  ('SIDOK', 24092, 125330583),
#  ('ABIM', 14377, 188613057),
#  ('ABIM TOWN COUNCIL', 11489, 115941152),
#  ('ALEREK', 12573, 1255760525),
#  ('LOTUKEI', 18641, 191684465),
#  ('MORULEM', 16834, 250364895),
#  ('KARITA', 45015, 658008801),
#  ('LOROO', 22541, 371970302),
# ...

# %%
#Sort the list of districts by total crop area (descending order).

# %%sql
SELECT DISTRICT_NAME, Crop_Area_Ha from Uganda
ORDER BY Crop_Area_Ha DESC;
# Out:
#  * sqlite://
# Done.
# [('KOTIDO', 13587.990759999999),
#  ('KOTIDO', 13278.52043),
#  ('KOTIDO', 10398.24939),
#  ('KOTIDO', 7087.823334000001),
#  ('KOTIDO', 7023.533691),
#  ('KAABONG', 6890.699234000001),
#  ('NAPAK', 6471.047334000001),
#  ('NAKAPIRIPIRIT', 5793.5076229999995),
#  ('NAKAPIRIPIRIT', 5759.618906000001),
#  ('NAPAK', 5473.443674),
#  ('NAKAPIRIPIRIT', 5079.779088),
#  ('KAABONG', 3934.432233),
#  ('NAKAPIRIPIRIT', 3276.653762),
#  ('NAKAPIRIPIRIT', 3264.534948),
#  ('NAPAK', 3120.318045),
#  ('NAPAK', 2990.847377),
#  ('KAABONG', 2834.349905),
#  ('KAABONG', 2700.676313),
#  ('AMUDAT', 2513.27183),
#  ('MOROTO', 2480.1219),
#  ('KAABONG', 2365.259806),
#  ('MOROTO', 2217.2907170000003),
#  ('NAKAPIRIPIRIT', 2008.0681690000001),
#  ('KAABONG', 1890.248613),
#  ('NAPAK', 1849.966589),
#  ('KOTIDO', 1656.5318550000002),
#  ('AMUDAT', 1651.99842),
#  ('AMUDAT', 1539.401382),
#  ('KAABONG', 1494.047587),
#  ('KAABONG', 1491.771813),
#  ('ABIM', 1266.109868),
# ...

# %%
#Select only the Sub counties from the Moroto district, order them 
#alphabetically  and show their production of sorghum.

# %%sql
SELECT SUBCOUNTY_NAME, DISTRICT_NAME, S_Prod_Tot from Uganda
WHERE DISTRICT_NAME = 'MOROTO'
ORDER BY SUBCOUNTY_NAME ASC;
# Out:
#  * sqlite://
# Done.
# [('KATIKEKILE', 'MOROTO', 9379.029413),
#  ('NADUNGET', 'MOROTO', 321630.539),
#  ('NORTHERN DIVISION', 'MOROTO', 17.28125956),
#  ('RUPA', 'MOROTO', 227298.5184),
#  ('SOUTHERN DIVISION', 'MOROTO', 19.67486547),
#  ('TAPAC', 'MOROTO', 49251.66081)]

# %%
#Compute the total Maize production per District.

# %%sql
SELECT  DISTINCT DISTRICT_NAME, M_Prod_Tot, SUM(M_Prod_Tot) from Uganda
GROUP BY DISTRICT_NAME
# Out:
#  * sqlite://
# Done.
# [('ABIM', 258010.2444, 1922133.1297),
#  ('AMUDAT', 2081.356199, 3546469.3324990002),
#  ('KAABONG', 136265.6835, 6990361.6143000005),
#  ('KOTIDO', 179681.139, 2010179.0731479998),
#  ('MOROTO', 155838.875, 422116.06882464996),
#  ('NAKAPIRIPIRIT', 1198586.875, 8125156.24546),
#  ('NAPAK', 414509.6206, 5587379.38888)]

# %%
#Compute the number of Sub counties where Maize is produced and the total Maize production per District.

# %%sql
SELECT DISTINCT DISTRICT_NAME,SUBCOUNTY_NAME, SUM(M_Prod_Tot), COUNT(SUBCOUNTY_NAME) from Uganda
GROUP BY DISTRICT_NAME;
# Out:
#  * sqlite://
# Done.
# [('ABIM', 'NYAKWAE', 1922133.1297, 6),
#  ('AMUDAT', 'AMUDAT TOWN COUNCIL', 3546469.3324990002, 4),
#  ('KAABONG', 'SIDOK', 6990361.6143000005, 14),
#  ('KOTIDO', 'RENGEN', 2010179.0731479998, 6),
#  ('MOROTO', 'RUPA', 422116.06882464996, 6),
#  ('NAKAPIRIPIRIT', 'MORUITA', 8125156.24546, 8),
#  ('NAPAK', 'LOKOPO', 5587379.38888, 8)]

# %%
#Compute the overall Crop area in all Sub counties where population is over 20000

# %%sql
SELECT SUM(Crop_Area_Ha) from Uganda
WHERE POP > 20000
# Out:
#  * sqlite://
# Done.
# [(120212.89015529997,)]

# %%
#Sort the Maize production in descending order by Districts, only taking into account
#  Sub counties where Maize area is larger than Sorghum area, and display the
#   number of Sub counties per district matching that criteria.
# %%sql
SELECT OBJECTID, DISTRICT_NAME, COUNT(SUBCOUNTY_NAME) from Uganda
WHERE M_Area_Ha > S_Area_Ha
GROUP BY DISTRICT_NAME
ORDER BY DISTRICT_NAME DESC;
# Out:
#  * sqlite://
# Done.
# [(1028, 'NAPAK', 2),
#  (1320, 'NAKAPIRIPIRIT', 3),
#  (928, 'MOROTO', 3),
#  (603, 'KAABONG', 3),
#  (812, 'AMUDAT', 1)]
